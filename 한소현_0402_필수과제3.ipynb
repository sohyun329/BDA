# %%
import pandas as pd
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
exam = pd.read_csv('/content/drive/MyDrive/exam.csv')
# Out:
# Mounted at /content/drive

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ##마커 종류
# - '.' point marker
# - ',' pixel marker
# - 'o' circle marker
# - 'v' triangle_down marker
# - '^' triangle_up marker
# - '<' triangle_left marker
# - '>' triangle_right marker
# - '1' tri_down marker
# - '2' tri_up marker
# - '3' tri_left marker
# - '4' tri_right marker
# - 's ' square marker
# - 'p' pentagon marker
# - '*' star marker
# - 'h' hexagon1 marker
# - 'H' hexagon2 marker
# - '+' plus marker
# - 'x' x marker
# - 'D' diamond marker
# - 'd' thin_diamond marker
# - '|' vline marker
# - '_' hline marker

# %% [markdown]
# ## 컬러
# - 'b' blue
# - 'g' green
# - 'r' red
# - 'c' cyan
# - 'm' magenta
# - 'y' yellow
# - 'k' black
# - 'w' white

# %% [markdown]
# ##라인 (linestyle=' ')
# - '-' solid line style
# - '--' dashed line style
# - '-.' dash-dot line style
# - ':' dotted line style

# %%
plt.plot(exam.id, exam.math, marker='.',label='math',color='g')
plt.plot(exam.id, exam.english, marker='.',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker=',',label='math',color='g')
plt.plot(exam.id, exam.english, marker=',',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='o',label='math',color='g')
plt.plot(exam.id, exam.english, marker='o',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='v',label='math',color='g')
plt.plot(exam.id, exam.english, marker='v',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='^',label='math',color='g')
plt.plot(exam.id, exam.english, marker='^',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='<',label='math',color='g')
plt.plot(exam.id, exam.english, marker='<',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='>',label='math',color='g')
plt.plot(exam.id, exam.english, marker='>',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='1',label='math',color='g')
plt.plot(exam.id, exam.english, marker='1',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='2',label='math',color='g')
plt.plot(exam.id, exam.english, marker='2',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='3',label='math',color='g')
plt.plot(exam.id, exam.english, marker='3',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='4',label='math',color='g')
plt.plot(exam.id, exam.english, marker='4',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='s',label='math',color='g')
plt.plot(exam.id, exam.english, marker='s',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='p',label='math',color='g')
plt.plot(exam.id, exam.english, marker='p',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='*',label='math',color='g')
plt.plot(exam.id, exam.english, marker='*',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='h',label='math',color='g')
plt.plot(exam.id, exam.english, marker='h',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='H',label='math',color='g')
plt.plot(exam.id, exam.english, marker='H',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='+',label='math',color='g')
plt.plot(exam.id, exam.english, marker='+',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='x',label='math',color='g')
plt.plot(exam.id, exam.english, marker='x',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='D',label='math',color='g')
plt.plot(exam.id, exam.english, marker='D',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='d',label='math',color='g')
plt.plot(exam.id, exam.english, marker='d',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='|',label='math',color='g')
plt.plot(exam.id, exam.english, marker='|',label='english',color='y')
plt.legend(loc='lower right')

# %%
plt.plot(exam.id, exam.math, marker='_',label='math',color='g')
plt.plot(exam.id, exam.english, marker='_',label='english',color='y')
plt.legend(loc='lower right')
