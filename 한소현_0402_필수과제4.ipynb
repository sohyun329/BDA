# %%
import pandas as pd
from matplotlib import pyplot as plt
from google.colab import drive
#import seaborn as sns
drive.mount('/content/drive')
exam = pd.read_csv('/content/drive/MyDrive/exam.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
exam_sp = exam.loc[:8]
exam_sp
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25
# 8   9       3    20       98       15

# %%
#sns.set(style = 'whitegrid')
plt.scatter(exam_sp.id, exam_sp.math, marker='*',color='g',label='math')
plt.scatter(exam_sp.id, exam_sp.english, marker=',',color='y',label='english')
plt.scatter(exam_sp.id, exam_sp.science, marker='D',color='m',label='science')
plt.legend()

# %%
plt.plot(exam_sp.id, exam_sp.math, marker='*',color='g',label='math')
plt.plot(exam_sp.id, exam_sp.english, marker=',',color='y',label='english')
plt.plot(exam_sp.id, exam_sp.science, marker='D',color='m',label='science')
plt.legend()
